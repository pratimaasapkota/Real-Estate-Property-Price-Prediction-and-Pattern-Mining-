# %%
import pandas as pd
import numpy as np

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("../data/raw/nepali_housing.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 2211
# Number of columns: 18

# %%
df.head()
# Out:
#                                                Title  \
# 0  Flat System House On Sale At Budhanikantha : H...
# 1  21 Aana Beautiful House : House For Sale In Bu...
# 2  Beautiful To Floor House : House For Sale In D...
# 3  Modern Architecture Bungalow House : House For...
# 4  Modern Bungalow House : House For Sale In Golf...
#
#                                     Address       City      Price  Bedroom  \
# 0  Budhanikantha, Budhanilkantha, Kathmandu  Kathmandu   90000000        6
# 1        Pasikot, Budhanilkantha, Kathmandu  Kathmandu   80000000        5
# 2               Dhapasi, Dhapasi, Kathmandu  Kathmandu   70000000        5
# 3           baluwatar, Baluwatar, Kathmandu  Kathmandu  130000000        6
# 4             Golfutar, Golfutar, Kathmandu  Kathmandu  100000000        6
#
#    Bathroom  Floors  Parking  Face    Year Views           Area  \
# 0         3     2.0       10  West  2073.0    17   1-0-0-0 Aana
# ...

# %%
print("Columns:")
print(df.columns.tolist())
# Out:
# Columns:
# ['Title', 'Address', 'City', 'Price', 'Bedroom', 'Bathroom', 'Floors', 'Parking', 'Face', 'Year', 'Views', 'Area', 'Road', 'Road Width', 'Road Type', 'Build Area', 'Posted', 'Amenities']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2211 entries, 0 to 2210
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       2211 non-null   object
#  1   Address     2211 non-null   object
#  2   City        2211 non-null   object
#  3   Price       2211 non-null   int64
#  4   Bedroom     2211 non-null   int64
#  5   Bathroom    2211 non-null   int64
#  6   Floors      1039 non-null   float64
#  7   Parking     2211 non-null   int64
#  8   Face        2211 non-null   object
#  9   Year        582 non-null    float64
#  10  Views       2211 non-null   object
#  11  Area        2211 non-null   object
#  12  Road        2211 non-null   object
#  13  Road Width  2211 non-null   object
#  14  Road Type   1426 non-null   object
#  15  Build Area  2211 non-null   object
#  16  Posted      2211 non-null   object
#  17  Amenities   2211 non-null   object
# dtypes: float64(2), int64(4), object(12)
# ...

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Title            0
# Address          0
# City             0
# Price            0
# Bedroom          0
# Bathroom         0
# Floors        1172
# Parking          0
# Face             0
# Year          1629
# Views            0
# Area             0
# Road             0
# Road Width       0
# Road Type      785
# Build Area       0
# Posted           0
# Amenities        0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df.describe(include="all")
# Out:
#                                      Title                        Address  \
# count                                 2211                           2211
# unique                                1502                           1588
# top     House For Sale In Imadol, Lalitpur  Na, Budhanilkantha, Kathmandu
# freq                                    38                             38
# mean                                   NaN                            NaN
# std                                    NaN                            NaN
# min                                    NaN                            NaN
# 25%                                    NaN                            NaN
# 50%                                    NaN                            NaN
# 75%                                    NaN                            NaN
# max                                    NaN                            NaN
#
#              City         Price      Bedroom     Bathroom       Floors  \
# ...

# %%
print("PRICE VALUES")
print(df["Price"].head(20).to_string(index=False))
# Out:
# PRICE VALUES
#  90000000
#  80000000
#  70000000
# 130000000
# 100000000
# 100000000
#  11000000
#  50000000
# 100000000
#  32500000
#  32000000
#  39900000
#  15000000
#  52500000
#  26500000
#  25500000
#  33000000
#  18500000
#  62000000
#  10500000

# %%
print("AREA VALUES")
print(df["Area"].head(20).to_string(index=False))
# Out:
# AREA VALUES
#  1-0-0-0 Aana
# 0-21-0-0 Aana
#  1-1-0-0 Aana
# 0-10-1-0 Aana
# 0-19-2-0 Aana
# 0-12-3-1 Aana
#    3-1-1 Aana
#  0-8-5-0 Aana
# 0-12-3-2 Aana
#  0-4-0-0 Aana
#       14 Aana
#  0-4-2-0 Aana
#        5 Aana
#        8 Aana
#        4 Aana
#        4 Aana
#  0-6-0-0 Aana
#        6 Aana
#       10 Aana
#  0-4-0-0 Aana

# %%
print("BUILD AREA VALUES")
print(df["Build Area"].head(20).to_string(index=False))
# Out:
# BUILD AREA VALUES
# 18-0-0-0 Aana
# 0-14-0-0 Aana
# 10-1-0-0 Aana
#  0-7-1-0 Aana
# 0-14-2-0 Aana
#  0-8-3-1 Aana
#      N/A Aana
#  0-6-5-0 Aana
#  0-9-3-2 Aana
#     2394 Aana
#        7 Aana
#     2500 Aana
#      N/A Aana
#      N/A Aana
#      N/A Aana
# 2700 Sq. Feet
#      N/A Aana
#      N/A Aana
#      N/A Aana
#      N/A Aana

# %%
print("ROAD WIDTH VALUES")
print(df["Road Width"].head(20).to_string(index=False))
# Out:
# ROAD WIDTH VALUES
# 20 Feet
# 20 Feet
# 20 Feet
# 20 Feet
# 20 Feet
# 13 Feet
# 11 Feet
# 20 Feet
# 20 Feet
# 12 Feet
# 15 Feet
# 14 Feet
# 12 Feet
# 20 Feet
# 13 Feet
# 13 Feet
# 20 Feet
#  13 Feet
#   0 Feet
#  10 Feet

# %%
print("VIEWS VALUES")
print(df["Views"].head(20).to_string(index=False))
# Out:
# VIEWS VALUES
#   17
#   26
#  154
#   17
#   59
#   92
#  317
#  618
#  110
# 2.6K
#  922
#  592
#  766
#  872
# 1.1K
# 1.6K
# 2.8K
#  404
#  164
#  460

# %%
print("AREA UNIQUE VALUES")
print(df["Area"].unique()[:30])

print("\nBUILD AREA UNIQUE VALUES")
print(df["Build Area"].unique()[:30])

print("\nROAD WIDTH UNIQUE VALUES")
print(df["Road Width"].unique()[:30])

print("\nPRICE UNIQUE VALUES")
print(df["Price"].unique()[:30])
# Out:
# AREA UNIQUE VALUES
# ['1-0-0-0 Aana' '0-21-0-0 Aana' '1-1-0-0 Aana' '0-10-1-0 Aana'
#  '0-19-2-0 Aana' '0-12-3-1 Aana' '3-1-1 Aana' '0-8-5-0 Aana'
#  '0-12-3-2 Aana' '0-4-0-0 Aana' '14 Aana' '0-4-2-0 Aana' '5 Aana' '8 Aana'
#  '4 Aana' '0-6-0-0 Aana' '6 Aana' '10 Aana' '0-3-2-0 Aana' '21 Aana'
#  '19 Aana' '6.1 Aana' '6.5 Aana' '0-3-0-0 Aana' '3-0-2 Aana' '4 Ropani'
#  '4 ana Aana' '7 Aana' '2500 Sq. Feet' '3.1 Aana']
#
# BUILD AREA UNIQUE VALUES
# ['18-0-0-0 Aana' '0-14-0-0 Aana' '10-1-0-0 Aana' '0-7-1-0 Aana'
#  '0-14-2-0 Aana' '0-8-3-1 Aana' 'N/A Aana' '0-6-5-0 Aana' '0-9-3-2 Aana'
#  '2394 Aana' '7 Aana' '2500 Aana' '2700 Sq. Feet' '2100 Sq. Feet'
#  'N/A Sq. Feet' '2700 Aana' '112 Sq. Meter' '3-0-2 Aana' '4 Aana'
#  '2200 Sq. Feet' '2000 Sq. Feet' '3 Aana' '4000 Sq. Feet'
#  '0-3-1-2 Sq. Feet' '1736 Dhur' '3500 Aana' '0-4-0-0 Aana' '1900 Sq. Feet'
#  '2500 Sq. Feet' '750 Aana']
#
# ROAD WIDTH UNIQUE VALUES
# ['20 Feet ' '13 Feet ' '11 Feet ' '12 Feet ' '15 Feet ' '14 Feet '
# ...

# %%
duplicate_count = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
print("Statistical Summary")
df.describe()
# Out:
# Statistical Summary
#               Price      Bedroom     Bathroom       Floors      Parking  \
# count  2.211000e+03  2211.000000  2211.000000  1039.000000  2211.000000
# mean   4.064428e+11     2.731796     1.871099     2.824206     1.007689
# std    7.564269e+12     4.174364     2.635836     1.265411     2.094905
# min    1.500000e+01     0.000000     0.000000     0.000000     0.000000
# 25%    1.300000e+06     0.000000     0.000000     2.000000     0.000000
# 50%    8.000000e+06     0.000000     0.000000     3.000000     0.000000
# 75%    2.650000e+07     5.000000     4.000000     3.000000     1.000000
# max    2.160000e+14    95.000000    40.000000    13.000000    31.000000
#
#               Year
# count   582.000000
# mean   2057.780069
# std      26.098577
# min    1994.000000
# 25%    2020.000000
# 50%    2074.000000
# 75%    2076.000000
# max    2077.000000

# %%
print("Categorical Columns Summary")
df.describe(include="object").T
# Out:
# Categorical Columns Summary
#            count unique                                 top  freq
# Title       2211   1502  House For Sale In Imadol, Lalitpur    38
# Address     2211   1588       Na, Budhanilkantha, Kathmandu    38
# City        2211     32                           Kathmandu  1483
# Face        2211      8                                East   745
# Views       2211    784                                1.2K    29
# Area        2211    604                              4 Aana   163
# Road        2211    176                              0 Feet   173
# Road Width  2211    100                            13 Feet    296
# Road Type   1426      6                         Blacktopped   749
# Build Area  2211    262                        N/A Sq. Feet   931
# Posted      2211     20                          1 year ago   506
# Amenities   2211    764                                  []  1067

# %%
print("Cities:")
print(df["City"].unique())

print("\nFaces:")
print(df["Face"].unique())

print("\nRoad Types:")
print(df["Road Type"].unique())
# Out:
# Cities:
# ['Kathmandu' 'Lalitpur' 'Pokhara' 'Bhaktapur' 'Chitwan' 'Butwal' 'Bara'
#  'Birtamod' 'Dharan' 'Sunsari' 'Makwanpur' 'Nawalpur' 'Kirtipur'
#  'Biratnagar' 'Parsa' 'Itahari' 'Jhapa' 'Mahottari' 'Dhading' 'Bardiya'
#  'Morang' 'Dang' 'Kavre' 'Kaski' 'Surkhet' 'Bhairahawa' 'Kapilvastu'
#  'Rupandehi' 'Tanahu' 'Illam' 'Nawalparasi' 'Kailali']
#
# Faces:
# ['West' 'East' 'South East' 'North' 'South West' 'North West' 'South'
#  'North East']
#
# Road Types:
# [' Blacktopped' ' Gravelled' ' Concrete' ' Paved' nan ' Soil Stabilized'
#  ' Alley']
